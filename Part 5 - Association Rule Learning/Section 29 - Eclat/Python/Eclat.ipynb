# %% [markdown]
# # Eclat

# %% [markdown]
# ## Importing the libraries

# %%
# !pip install apyori

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Data Preprocessing

# %%
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)
transactions = []
for i in range(0, 7501):
  transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %% [markdown]
# ## Training the Eclat model on the dataset

# %%
from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 3, max_length = 3)

# %% [markdown]
# ## Visualising the results

# %% [markdown]
# ### Displaying the first results coming directly from the output of the apriori function

# %%
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'light cream', 'chicken'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'mushroom cream sauce', 'escalope'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'pasta', 'escalope'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
# ...

# %% [markdown]
# ### Putting the results well organised into a Pandas DataFrame

# %%
def inspect(results):
    fhs         = [tuple(result[2][0][0])[0] for result in results]
    shs         = [tuple(result[2][0][0])[1] for result in results]
    ths         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    return list(zip(fhs, shs,ths, supports))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Product 1','product 2', 'Product 3', 'Support'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-011639672923> in <module>()
#       5     supports    = [result[1] for result in results]
#       6     return list(zip(fhs, shs,ths, supports))
# ----> 7 resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Product 1','product 2', 'Product 3', 'Support'])
#
# <ipython-input-11-011639672923> in inspect(results)
#       1 def inspect(results):
#       2     fhs         = [tuple(result[2][0][0])[0] for result in results]
# ----> 3     shs         = [tuple(result[2][0][0])[1] for result in results]
#       4     ths         = [tuple(result[2][0][1])[0] for result in results]
#       5     supports    = [result[1] for result in results]
#
# <ipython-input-11-011639672923> in <listcomp>(.0)
#       1 def inspect(results):
#       2     fhs         = [tuple(result[2][0][0])[0] for result in results]
# ...

# %% [markdown]
# ### Displaying the results sorted by descending supports

# %%
resultsinDataFrame.nlargest(n = 20, columns = 'Support')
